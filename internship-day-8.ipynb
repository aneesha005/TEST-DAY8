# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# allow plots to appear directly in the notebook
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv(r"D:\Norka\Intenship\dataset\250000 Records-new..csv")

# %%
df
# Out:
#         Emp ID Name Prefix First Name Gender  Age in Yrs Date of Joining  \
# 0       857211         Ms.    Hermila      F          24      09-09-2014
# 1       514341         Mr.    Antonio      M          27      08-02-2011
# 2       314598       Prof.  Sebastian      M          36      04-01-2012
# 3       987773         Mr.       Alec      M          43       3-19-1998
# 4       690850         Mr.     Reggie      M          50      01-04-2010
# ...        ...         ...        ...    ...         ...             ...
# 249994  416214         Mr.     Tracey      M          47       3-29-2007
# 249995  804940         Mr.       Alan      M          29      11-01-2015
# 249996  484412         Mr.    Francis      M          55      11-29-1992
# 249997  853493         Ms.      Edith      F          28      02-12-2017
# 249998  134870        Mrs.     Moriah      F          46      08-11-2011
#
#         Age in Company (Years)        Country     Region  Salary
# 0                            2           Clay      South  168991
# 1                            5        Screven      South   53504
# 2                            5      Jefferson  Northeast  158859
# 3                           19  Milledgeville      South   76105
# 4                            7         Greene    Midwest  134436
# ...                        ...            ...        ...     ...
# 249994                      11       Columbia      South  170139
# 249995                       1       Plymouth  Northeast   84230
# 249996                      24        Fremont       West   74172
# 249997                       1        Kingman    Midwest  137696
# 249998                       5        Letcher      South   77074
#
# [249999 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249999 entries, 0 to 249998
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Emp ID                  249999 non-null  int64
#  1   Name Prefix             249999 non-null  object
#  2   First Name              249999 non-null  object
#  3   Gender                  249999 non-null  object
#  4   Age in Yrs              249999 non-null  int64
#  5   Date of Joining         249999 non-null  object
#  6   Age in Company (Years)  249999 non-null  int64
#  7   Country                 249999 non-null  object
#  8   Region                  249999 non-null  object
#  9   Salary                  249999 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 19.1+ MB

# %%
df.isnull().sum()
# Out:
# Emp ID                    0
# Name Prefix               0
# First Name                0
# Gender                    0
# Age in Yrs                0
# Date of Joining           0
# Age in Company (Years)    0
# Country                   0
# Region                    0
# Salary                    0
# dtype: int64

# %%
df.describe()
# Out:
#               Emp ID     Age in Yrs  Age in Company (Years)         Salary
# count  249999.000000  249999.000000           249999.000000  249999.000000
# mean   555637.933052      39.986348                9.423846  120012.677971
# std    256626.164618      11.226959                8.474282   46213.396976
# min    111118.000000      21.000000                1.000000   40000.000000
# 25%    333388.500000      30.000000                2.000000   79930.500000
# 50%    556113.000000      40.000000                7.000000  120024.000000
# 75%    777772.500000      50.000000               14.000000  160065.000000
# max    999995.000000      60.000000               38.000000  200000.000000

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 249994    False
# 249995    False
# 249996    False
# 249997    False
# 249998    False
# Length: 249999, dtype: bool

# %%
df.duplicated("Emp ID")
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 249994     True
# 249995    False
# 249996     True
# 249997     True
# 249998    False
# Length: 249999, dtype: bool

# %%
df.shape
# Out:
# (249999, 10)

# %%
df=df.drop_duplicates("Emp ID")

# %%
df.shape
# Out:
# (219433, 10)

# %%
df.dtypes
# Out:
# Emp ID                     int64
# Name Prefix               object
# First Name                object
# Gender                    object
# Age in Yrs                 int64
# Date of Joining           object
# Age in Company (Years)     int64
# Country                   object
# Region                    object
# Salary                     int64
# dtype: object

# %%
df.head(15)
# Out:
#     Emp ID Name Prefix First Name Gender  Age in Yrs Date of Joining  \
# 0   857211         Ms.    Hermila      F          24      09-09-2014
# 1   514341         Mr.    Antonio      M          27      08-02-2011
# 2   314598       Prof.  Sebastian      M          36      04-01-2012
# 3   987773         Mr.       Alec      M          43       3-19-1998
# 4   690850         Mr.     Reggie      M          50      01-04-2010
# 5   358257       Prof.     Elisha      M          44       5-22-2015
# 6   303899         Mr.     Danilo      M          52       2-14-1994
# 7   901163         Ms.   Madalene      F          59       3-21-2011
# 8   640135        Drs.    Micheal      F          47       9-13-2001
# 9   775378        Mrs.      Wilma      F          50       7-19-1998
# 10  257614       Prof.      Jorge      M          47      10-31-2013
# 11  313674         Mr.      Isaac      M          34      05-04-2005
# 12  359415         Mr.    Emerson      M          45       5-24-1993
# 13  858207         Mr.     Booker      M          37      11-17-2006
# 14  731568       Prof.  Margarito      M          27       5-22-2014
#
#     Age in Company (Years)         Country     Region  Salary
# 0                        2            Clay      South  168991
# 1                        5         Screven      South   53504
# 2                        5       Jefferson  Northeast  158859
# 3                       19   Milledgeville      South   76105
# 4                        7          Greene    Midwest  134436
# 5                        2          Chelan       West  119237
# 6                       23            Polk    Midwest  115449
# 7                        6        Columbia       West  104968
# 8                       15        Trumbull    Midwest   71948
# 9                       19        Doña Ana       West  114397
# 10                       3       St. Croix    Midwest  106883
# 11                      12     Los Angeles       West   79923
# 12                      24         Johnson    Midwest  179309
# 13                      11  Northumberland      South   55634
# 14                       3            Polk       West  173211

# %%
df.value_counts("Region")
# Out:
# Region
# South        81508
# Midwest      60071
# West         38968
# Northeast    38886
# dtype: int64

# %%
df.value_counts("First Name")
# Out:
# First Name
# Adam         148
# Kelley       146
# Richard      145
# Blake        144
# Jan          142
#             ...
# Jeraldine     13
# Edythe        12
# Phebe         12
# Ellyn         12
# Latonia       12
# Length: 5163, dtype: int64

# %%
df.value_counts("Name Prefix")
# Out:
# Name Prefix
# Mr.      76943
# Ms.      48575
# Mrs.     36611
# Hon.     23122
# Drs.     12343
# Dr.      10999
# Prof.    10840
# dtype: int64

# %%
df.value_counts("Country")
# Out:
# Country
# Los Angeles    2670
# Jefferson      2605
# Washington     2501
# Montgomery     2066
# Orange         1834
#                ...
# Burnwell          1
# Poe               1
# Dover             1
# Eagleville        1
# Underhill         1
# Length: 2746, dtype: int64

# %%
df[["Emp ID", "Name Prefix","First Name", "Gender", "Age in Yrs", "Date of Joining", "Age in Company (Years)", "Country","Region","Salary"]] =df[["Emp ID", "Name Prefix","First Name", "Gender", "Age in Yrs", "Date of Joining", "Age in Company (Years)", "Country","Region","Salary"]].replace(0,np.NaN)

# %%
df.isnull().sum()
# Out:
# Emp ID                    0
# Name Prefix               0
# First Name                0
# Gender                    0
# Age in Yrs                0
# Date of Joining           0
# Age in Company (Years)    0
# Country                   0
# Region                    0
# Salary                    0
# dtype: int64

# %%
df.hist(bins=50,figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'Emp ID'}>,
#         <AxesSubplot:title={'center':'Age in Yrs'}>],
#        [<AxesSubplot:title={'center':'Age in Company (Years)'}>,
#         <AxesSubplot:title={'center':'Salary'}>]], dtype=object)

# %%
df["Age in Yrs"].value_counts().plot(kind='pie', title='Age in Yrs',figsize=(10,5))
plt.show()

# %%
df["Age in Company (Years)"].value_counts().plot(kind='pie', title='Age in Company (Years)',figsize=(10,5))
plt.show()

# %%
df["Region"].value_counts().plot(kind='pie', title='Region',figsize=(10,5))
plt.show()

# %%
sns.countplot(df.Salary,hue=df.Gender)
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='count'>

# %%
sns.countplot(df.Salary,hue=df.Age in Company (Years))

# %%
sns.factorplot(x="Salary", data = df, kind = "count", hue = "Region")
plt.show()

# %%
sns.factorplot(x="Salary", data = df, kind = "count", hue = "Age in Company (Years)")
plt.show()
